# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib as mpl 
import matplotlib.pyplot as plt
# %matplotlib inline
data = pd.read_csv("data.csv")

print ("data read into the data frame")
# Out:
# data read into the data frame

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1309 non-null   object
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1309 non-null   object
#  9   cabin      1309 non-null   object
#  10  embarked   1309 non-null   object
#  11  boat       1309 non-null   object
#  12  body       1309 non-null   object
#  13  home.dest  1309 non-null   object
# dtypes: int64(4), object(10)
# memory usage: 143.3+ KB

# %%
data.replace("?", np.nan, inplace=True)
data = data.astype({"age":np.float64, "fare":np.float64})

# %%
fig, axs = plt.subplots(ncols=5, figsize=(30,5))
sns.violinplot(x="survived", y="age", hue="sex", data=data, ax=axs[0])
sns.pointplot(x="sibsp", y="survived", hue="sex", data=data, ax=axs[1])
sns.pointplot(x="parch", y="survived", hue="sex", data=data, ax=axs[2])
sns.pointplot(x="pclass", y="survived", hue="sex", data=data, ax=axs[3])
sns.violinplot(x="survived", y="fare", hue="sex", data=data, ax=axs[4])

# %%
data.corr().abs()[["survived"]]
# Out:
#           survived
# pclass    0.312469
# survived  1.000000
# sex       0.528693
# age       0.055513
# sibsp     0.027825
# parch     0.082660
# fare      0.244265

# %%
data = data[['sex', 'pclass','age','fare','survived']].dropna()
data.head()
# Out:
#    sex  pclass      age      fare  survived
# 0    0       1  29.0000  211.3375         1
# 1    1       1   0.9167  151.5500         1
# 2    0       1   2.0000  151.5500         0
# 3    1       1  30.0000  151.5500         0
# 4    0       1  25.0000  151.5500         0

# %%
data.head()
# Out:
#    sex  pclass      age      fare  survived
# 0    0       1  29.0000  211.3375         1
# 1    1       1   0.9167  151.5500         1
# 2    0       1   2.0000  151.5500         0
# 3    1       1  30.0000  151.5500         0
# 4    0       1  25.0000  151.5500         0

# %%
#Divide up the dataset into training and test (validation) data using train_test_split
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(data[['sex','pclass','age','fare']], data.survived, test_size=0.2, random_state=0)

# %%
#Normalize the inputs such that all features are treated equally using the Standard Scaler
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(x_train)
X_test = sc.transform(x_test)

# %%
#Use Machine Learning to Model(Train) the Data using the Gaussian Naive Bayes Model
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
#Testing the model using the Test Data
#The 
from sklearn import metrics
predict_test = model.predict(X_test)
print(metrics.accuracy_score(y_test, predict_test))
# Out:
# 0.7799043062200957

# %% [markdown]
# THe algorithm has a success rate of 78%

# %%
#A neural network can be used to improve the accuracy of the model
#Use the Keras library with TensorFlow to construct the neural network

#import the required libraries.
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-61-22d6214973e7> in <module>
#       3
#       4 #import the required libraries.
# ----> 5 import Keras
#       6 from Keras.models import Sequential
#       7 from Keras.layers import Dense
#
# ModuleNotFoundError: No module named 'Keras'

# %%
 # import the required libraries and to create the model.
 model = Sequential()
